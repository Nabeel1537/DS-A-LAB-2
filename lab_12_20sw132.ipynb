# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabeel1537/DS-A-LAB-2/blob/main/lab_12_20sw132.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Fetch a web page
r = requests.get("https://sheerazalee223.medium.com/mastering-sales-forecasting-a-deep-dive-into-time-series-prediction-with-linear-regression-70703ddac138")
print(r.text)
# Out:
# <!doctype html><html lang="en"><head><title data-rh="true">Mastering Sales Forecasting: A Deep Dive into Time Series Prediction with Linear Regression | by Sheerazalee | Oct, 2023 | Medium</title><meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1"/><meta data-rh="true" name="theme-color" content="#000000"/><meta data-rh="true" name="twitter:app:name:iphone" content="Medium"/><meta data-rh="true" name="twitter:app:id:iphone" content="828256236"/><meta data-rh="true" property="al:ios:app_name" content="Medium"/><meta data-rh="true" property="al:ios:app_store_id" content="828256236"/><meta data-rh="true" property="al:android:package" content="com.medium.reader"/><meta data-rh="true" property="fb:app_id" content="542599432471018"/><meta data-rh="true" property="og:site_name" content="Medium"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="article:
# ...

# %%
import re

# Remove HTML tags using RegularExpression
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# Mastering Sales Forecasting: A Deep Dive into Time Series Prediction with Linear Regression | by Sheerazalee | Oct, 2023 | Medium{"@context":"http:\u002F\u002Fschema.org","@type":"NewsArticle","image":["https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fresize:fit:1200\u002F1*Yy-jz5sEwuL9AYa4lYdtoQ.jpeg"],"url":"https:\u002F\u002Fsheerazalee223.medium.com\u002Fmastering-sales-forecasting-a-deep-dive-into-time-series-prediction-with-linear-regression-70703ddac138","dateCreated":"2023-10-07T15:34:58.163Z","datePublished":"2023-10-07T15:34:58.163Z","dateModified":"2023-10-07T15:43:10.969Z","headline":"Mastering Sales Forecasting: A Deep Dive into Time Series Prediction with Linear Regression","name":"Mastering Sales Forecasting: A Deep Dive into Time Series Prediction with Linear Regression","description":"Introduction: Sales forecasting is the lifeblood of any retail business. It empowers decision-makers to optimize inventory, plan marketing strategies, and allocate resources effectively. 
# ...

# %%
from bs4 import BeautifulSoup

# %%
# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# Mastering Sales Forecasting: A Deep Dive into Time Series Prediction with Linear Regression | by Sheerazalee | Oct, 2023 | Medium{"@context":"http:\u002F\u002Fschema.org","@type":"NewsArticle","image":["https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fresize:fit:1200\u002F1*Yy-jz5sEwuL9AYa4lYdtoQ.jpeg"],"url":"https:\u002F\u002Fsheerazalee223.medium.com\u002Fmastering-sales-forecasting-a-deep-dive-into-time-series-prediction-with-linear-regression-70703ddac138","dateCreated":"2023-10-07T15:34:58.163Z","datePublished":"2023-10-07T15:34:58.163Z","dateModified":"2023-10-07T15:43:10.969Z","headline":"Mastering Sales Forecasting: A Deep Dive into Time Series Prediction with Linear Regression","name":"Mastering Sales Forecasting: A Deep Dive into Time Series Prediction with Linear Regression","description":"Introduction: Sales forecasting is the lifeblood of any retail business. It empowers decision-makers to optimize inventory, plan marketing strategies, and allocate resources effectively. 
# ...

# %%
#mw-content-container
# Find all articles
summaries = soup.find_all("div", class_="l")
summaries[0]
# Out:
# <div class="l c"><div class="l m n o c"><div class="p q r s t u v w x i d y z"></div><div class="p q r ab ac"><div class="ab q ae"><a aria-label="Homepage" class="af ag ah ai aj ak al am an ao ap aq ar as at ab" data-testid="headerMediumLogo" href="https://medium.com/?source=---two_column_layout_nav----------------------------------" rel="noopener follow"><svg class="au av" viewBox="0 0 1043.63 592.71"><g data-name="Layer 2"><g data-name="Layer 1"><path d="M588.67 296.36c0 163.67-131.78 296.35-294.33 296.35S0 460 0 296.36 131.78 0 294.34 0s294.33 132.69 294.33 296.36M911.56 296.36c0 154.06-65.89 279-147.17 279s-147.17-124.94-147.17-279 65.88-279 147.16-279 147.17 124.9 147.17 279M1043.63 296.36c0 138-23.17 249.94-51.76 249.94s-51.75-111.91-51.75-249.94 23.17-249.94 51.75-249.94 51.76 111.9 51.76 249.94"></path></g></g></svg></a><div class="aw h"><div class="ab ax ay az ba q bb bc"><div aria-describedby="searchResults" aria-hidden="false" aria-labelledby="searchResults" class="bl"></d
# ...

# %%
scraped_data = summaries[0].get_text().strip()

# %%
scraped_data = scraped_data.lower()
print(scraped_data)
# Out:
# mastering sales forecasting: a deep dive into time series prediction with linear regressionsheerazalee·follow4 min read·2 days ago--listensharemembers:20sw050, 20sw120, 20sw132introduction: sales forecasting is the lifeblood of any retail business. it empowers decision-makers to optimize inventory, plan marketing strategies, and allocate resources effectively. in this article, we will embark on an in-depth exploration of time series forecasting using linear regression. we’ll walk through the entire process: from data preparation to model training and evaluation, and finally, we’ll visualize the results with insightful diagrams.understanding the data:our dataset, sourced from a fictitious store, comprises historical sales data. our goal is to predict monthly sales for the upcoming year, leveraging past sales patterns.# importing essential libraries and loading the dataset import os import pandas as pd import numpy as np import matplotlib.pyplot as plt from sklearn.linear_model import 
# ...

# %%
import re

# Remove punctuation characters
scraped_data = re.sub(r"[^a-zA-Z0-9]", " ", scraped_data)
print(scraped_data)
# Out:
# mastering sales forecasting  a deep dive into time series prediction with linear regressionsheerazalee follow4 min read 2 days ago  listensharemembers 20sw050  20sw120  20sw132introduction  sales forecasting is the lifeblood of any retail business  it empowers decision makers to optimize inventory  plan marketing strategies  and allocate resources effectively  in this article  we will embark on an in depth exploration of time series forecasting using linear regression  we ll walk through the entire process  from data preparation to model training and evaluation  and finally  we ll visualize the results with insightful diagrams understanding the data our dataset  sourced from a fictitious store  comprises historical sales data  our goal is to predict monthly sales for the upcoming year  leveraging past sales patterns   importing essential libraries and loading the dataset import os import pandas as pd import numpy as np import matplotlib pyplot as plt from sklearn linear model import 
# ...

# %%
# Split text into tokens (words)
data = scraped_data.split()
print(data)
# Out:
# ['mastering', 'sales', 'forecasting', 'a', 'deep', 'dive', 'into', 'time', 'series', 'prediction', 'with', 'linear', 'regressionsheerazalee', 'follow4', 'min', 'read', '2', 'days', 'ago', 'listensharemembers', '20sw050', '20sw120', '20sw132introduction', 'sales', 'forecasting', 'is', 'the', 'lifeblood', 'of', 'any', 'retail', 'business', 'it', 'empowers', 'decision', 'makers', 'to', 'optimize', 'inventory', 'plan', 'marketing', 'strategies', 'and', 'allocate', 'resources', 'effectively', 'in', 'this', 'article', 'we', 'will', 'embark', 'on', 'an', 'in', 'depth', 'exploration', 'of', 'time', 'series', 'forecasting', 'using', 'linear', 'regression', 'we', 'll', 'walk', 'through', 'the', 'entire', 'process', 'from', 'data', 'preparation', 'to', 'model', 'training', 'and', 'evaluation', 'and', 'finally', 'we', 'll', 'visualize', 'the', 'results', 'with', 'insightful', 'diagrams', 'understanding', 'the', 'data', 'our', 'dataset', 'sourced', 'from', 'a', 'fictitious', 'store', 'comprises',
# ...

# %%
#natural language processing kit
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
# Another sample text
text = "mastering sales forecasting  a deep dive into time series prediction with linear regressionsheerazalee follow4 min read 2 days ago"
print(text)
# Out:
# mastering sales forecasting  a deep dive into time series prediction with linear regressionsheerazalee follow4 min read 2 days ago

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['mastering', 'sales', 'forecasting', 'a', 'deep', 'dive', 'into', 'time', 'series', 'prediction', 'with', 'linear', 'regressionsheerazalee', 'follow4', 'min', 'read', '2', 'days', 'ago']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['mastering sales forecasting  a deep dive into time series prediction with linear regressionsheerazalee follow4 min read 2 days ago']

# %%
# List stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# ...

# %%
# Reset text
text = "mastering sales forecasting  a deep dive into time series prediction with linear regressionsheerazalee follow4 min read 2 days ago"
# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['mastering', 'sales', 'forecasting', 'a', 'deep', 'dive', 'into', 'time', 'series', 'prediction', 'with', 'linear', 'regressionsheerazalee', 'follow4', 'min', 'read', '2', 'days', 'ago']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['mastering', 'sales', 'forecasting', 'deep', 'dive', 'time', 'series', 'prediction', 'linear', 'regressionsheerazalee', 'follow4', 'min', 'read', '2', 'days', 'ago']

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['master', 'sale', 'forecast', 'deep', 'dive', 'time', 'seri', 'predict', 'linear', 'regressionsheerazale', 'follow4', 'min', 'read', '2', 'day', 'ago']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['mastering', 'sale', 'forecasting', 'deep', 'dive', 'time', 'series', 'prediction', 'linear', 'regressionsheerazalee', 'follow4', 'min', 'read', '2', 'day', 'ago']

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['master', 'sale', 'forecast', 'deep', 'dive', 'time', 'series', 'prediction', 'linear', 'regressionsheerazalee', 'follow4', 'min', 'read', '2', 'day', 'ago']
